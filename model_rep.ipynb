# %%
import os
print("Hello world")
print(os.listdir())
# Out:
# Hello world
# ['.config', 'deeplearning.mplstyle', 'sample_data']

# %% [markdown]
# Tools i need in this library
# Numpy
# Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# This lab i am using simple data

# %%
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train= {x_train}")
print(f"y_train = { y_train}")
# Out:
# x_train= [1. 2.]
# y_train = [300. 500.]

# %% [markdown]
# m to denote number of the training example

# %%
m = x_train.shape[0]
print(f"m = {m}")
# Out:
# m = 2

# %% [markdown]
# using x(i) and y(i) to denote ith training example

# %%
i =0 
x_i = x_train[i]
y_i = y_train[i]
print(f"x_i = {x_i}, y_i = {y_i}")
# Out:
# x_i = 1.0, y_i = 300.0

# %% [markdown]
# Ploting data by using scatter() from matplotlib

# %%
# plotting data
plt.scatter(x_train, y_train, marker="x", c="r")
# set the title
plt.title("Housing Prices")
# set x and y labels
plt.ylabel('Price (in 1000s of dollars)')
plt.xlabel('Size (1000 sqft)')
plt.show()

# %% [markdown]
# Model function  is function that maps x and y ...f(x) = wx+b

# %%
w =100
b =100

# compute the model's prediction y hat for the examples in x_new
def compute_model (x, w, b):
    m = x.shape[0]
    f_wb = np.zeros(m)
    
    for i in range (m):
        f_wb[i] = w * x[i] + b
    return f_wb


plt.plot(x_train , compute_model(x_train, w, b), marker=".", c='g', label="Our prediction" )
plt.scatter(x_train, y_train, marker="x", c="r", label="Actual values")
plt.title("Housing Prices")
plt.xlabel("Size (1000 sqft)")
plt.ylabel("Price (in 1000s of dollars)")
plt.legend()
print(compute_model(x_train, w, b))
plt.show()
# Out:
# [200. 300.]
